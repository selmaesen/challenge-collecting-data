# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
#iterate the pages and generate url for them
base_url = "https://www.immoweb.be/en/search/house/for-sale?countries=BE&"
for i in range (1,334):
    new_url = base_url + "page="+ str(i) +"&orderBy=newest"

# %% [markdown]
# Locality
# Type of property (House/apartment)
# Subtype of property (Bungalow, Chalet, Mansion, ...)
# Price
# Type of sale (Exclusion of life sales)
# Number of rooms
# Area
# Fully equipped kitchen (Yes/No)
# Furnished (Yes/No)
# Open fire (Yes/No)
# Terrace (Yes/No)
# If yes: Area
# Garden (Yes/No)
# If yes: Area
# Surface of the land
# Surface area of the plot of land
# Number of facades
# Swimming pool (Yes/No)
# State of the building (New, to be renovated, ...)

# %%
#work on single adv. 
one_ad = open ("/Users/mselmaesen/Desktop/challenge-collecting-data/one_ad", "w")

url = "https://www.immoweb.be/en/classified/house/for-sale/jodoigne/1370/8948563?searchId=5f6b4b626f5b7"
response = requests.get(url)
print(response.status_code)
if response.ok:
    
    soup = BeautifulSoup(response.text, "lxml")
    price = soup.find("span",{"aria-hidden":"true"})
    print (price)
    print (price.text)
    
    #Locality ----Ankita

    #Type of property (House/apartment)

    prop_types = ["House","Apartment"] 

    prop_subtype = ["Town house","Mansion","Mixed-use building","Pavilion","Villa","Farm house",
                  "Country cottage", "Castle", "Bungalow", "Chalet","Manor house","Exceptional property",
                  "Other property"]
    
    type_prop = soup.find("div",{"class":"classified__header-content"}).find("h1",{"class":"classified__title"})
    
    type_prop = type_prop.text
    
    for i in prop_types:
        print (i)
        if i in type_prop:
            type_prop= i
    
    for j in prop_subtype:
        if j in type_prop:
            subtype_prop = j
        else:
            subtype_prop = "None"
            
        
    house_facades = soup.find("table", {"class" : "classified-table"})
    #print(house_facades)
    

    for table in soup.find_all("table"):
        for td in soup.find_all("th"):
            print (td)
        #print (table)
    #print (soup.find("th"))
    list_a = []
    string = ""
    for th in soup.find_all("th", {"class":"classified-table__header","scope":"row"}):
        string = string + "\n" + str(th)
        #print (th.text)
        
        
        list_a.append(str(th))
    print (list_a)
   

    # Fully equipped kitchen (Yes/No)
    
    
    

    

#Subtype of property (Bungalow, Chalet, Mansion, ...)

#Type of sale (Exclusion of life sales)
#Number of rooms
#Area
#Fully equipped kitchen (Yes/No)
#Furnished (Yes/No)
#Open fire (Yes/No)
#Terrace (Yes/No)
#If yes: Area
#Garden (Yes/No)
#If yes: Area
#Surface of the land
#Surface area of the plot of land
#Number of facades
#Swimming pool (Yes/No)
#State of the building (New, to be renovated, ...)
    #room_num = soup.find()
    
   # country = soup.find('tr', {'id' : "places_countryrow"}).find('td', {'class': 'w2p_fw'})
# Out:
# 200
# <span aria-hidden="true">€350,000</span>
# €350,000
# House
# Apartment
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th colspan="2">
# <img alt="" class="classified-table__picture" src="https://static.immoweb.be/pics/peb/peb_c.png"/>
# </th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>
# ['<th class="classified-table__header" scope="row">Available as of</th>', '<th class="classified-table__header" scope="row">\n                                    Neighbourhood or locality\n                                </th>', '<th class="classified-table__header" scope="row">\n                                    Building condition\n                                </th>', '<th class="classified-table__header" scope="row">\n                                    Facades\n                                </th>', '<th class="classified-table__header" scope="row">Outdoor parking spaces</th>', '<th class="classified-table__header" scope="row">\n                                    Living area\n                                </th>', '<th class="classified-table__header" scope="row">Kitchen type</th>', '<th class="classified-table__header" scope="row">Bedrooms</th>', '<th class="classified-table__header" scope="row">\n                                        Bedroom 1 surface\n                                    </th>', '<th class="classified-table__header" scope="row">\n                                        Bedroom 2 surface\n                                    </th>', '<th class="classified-table__header" scope="row">\n                                        Bedroom 3 surface\n                                    </th>', '<th class="classified-table__header" scope="row">Bathrooms</th>', '<th class="classified-table__header" scope="row">Toilets</th>', '<th class="classified-table__header" scope="row">Surface of the plot</th>', '<th class="classified-table__header" scope="row">Land plot to rear</th>', '<th class="classified-table__header" scope="row">Flat land</th>', '<th class="classified-table__header" scope="row">Connection to sewer network</th>', '<th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>', '<th class="classified-table__header" scope="row">Garden surface</th>', '<th class="classified-table__header" scope="row">Terrace</th>', '<th class="classified-table__header" scope="row">Terrace orientation</th>', '<th class="classified-table__header" scope="row">Number of annexes</th>', '<th class="classified-table__header" scope="row">Primary energy consumption</th>', '<th class="classified-table__header" scope="row">Energy class</th>', '<th class="classified-table__header" scope="row">Reference number of the EPC report</th>', '<th class="classified-table__header" scope="row">CO² emission</th>', '<th class="classified-table__header" scope="row">\n                                Yearly theoretical total energy consumption\n                            </th>', '<th class="classified-table__header" scope="row">Heating type</th>', '<th class="classified-table__header" scope="row">Double glazing</th>', '<th class="classified-table__header" scope="row">Planning permission obtained</th>', '<th class="classified-table__header" scope="row">Latest land use designation</th>', '<th class="classified-table__header" scope="row">Price</th>', '<th class="classified-table__header" scope="row">Cadastral income</th>']

# %%
prop_types = ["house", "town house","mansion","apartment","mixed-use building","Pavilion","Villa","Farm house","Country cottage", "Castle", "Bungalow", "Chalet","Manor house","Exceptional property","Other property"]

# %%
print (soup.find(id="accordion_a394df75-3eae-4a0f-9b85-f9d1bb9fb1ec"))
# Out:
# None

# %%
soup.find (atters = {"class" : "table-block"})

# %%
s=""
sd="12"
s = sd + "\n" +"wed"
print (s)
# Out:
# 12
# wed

# %%
print (string)
# Out:
# <th class="classified-table__header" scope="row">Available as of</th>
# <th class="classified-table__header" scope="row">
#                                     Neighbourhood or locality
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Building condition
#                                 </th>
# <th class="classified-table__header" scope="row">
#                                     Facades
#                                 </th>
# <th class="classified-table__header" scope="row">Outdoor parking spaces</th>
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 1 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 2 surface
#                                     </th>
# <th class="classified-table__header" scope="row">
#                                         Bedroom 3 surface
#                                     </th>
# <th class="classified-table__header" scope="row">Bathrooms</th>
# <th class="classified-table__header" scope="row">Toilets</th>
# <th class="classified-table__header" scope="row">Surface of the plot</th>
# <th class="classified-table__header" scope="row">Land plot to rear</th>
# <th class="classified-table__header" scope="row">Flat land</th>
# <th class="classified-table__header" scope="row">Connection to sewer network</th>
# <th class="classified-table__header" scope="row">Gas, water &amp; electricity</th>
# <th class="classified-table__header" scope="row">Garden surface</th>
# <th class="classified-table__header" scope="row">Terrace</th>
# <th class="classified-table__header" scope="row">Terrace orientation</th>
# <th class="classified-table__header" scope="row">Number of annexes</th>
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <th class="classified-table__header" scope="row">Energy class</th>
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <th class="classified-table__header" scope="row">CO² emission</th>
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <th class="classified-table__header" scope="row">Heating type</th>
# <th class="classified-table__header" scope="row">Double glazing</th>
# <th class="classified-table__header" scope="row">Planning permission obtained</th>
# <th class="classified-table__header" scope="row">Latest land use designation</th>
# <th class="classified-table__header" scope="row">Price</th>
# <th class="classified-table__header" scope="row">Cadastral income</th>

# %%
import re


print (list_a[27])  
pattern2 = ">+\w+\s?\w?+<"
pattern3 = ">+[A-Za-z,;'\"\\s]+[.?!]$+<"
pattern4 = ">+\w+\\s?+\w?+<"
for n in list_a:
    print(re.findall(pattern3,n))
    
print (type(list_a[27]))
print ()
# Out:
# <th class="classified-table__header" scope="row">Heating type</th>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-128-5d9e071ac001> in <module>
#       7 pattern4 = ">+\w+\\s?+\w?+<"
#       8 for n in list_a:
# ----> 9     print(re.findall(pattern3,n))
#      10
#      11 print (type(list_a[27]))
#
# ~/opt/anaconda3/lib/python3.8/re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# ~/opt/anaconda3/lib/python3.8/re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~/opt/anaconda3/lib/python3.8/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~/opt/anaconda3/lib/python3.8/sre_parse.py in parse(str, flags, state)
#     946
#     947     try:
# --> 948         p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949     except Verbose:
#     950         # the VERBOSE flag was switched on inside the pattern.  to be
#
# ~/opt/anaconda3/lib/python3.8/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     441     start = source.tell()
#     442     while True:
# --> 443         itemsappend(_parse(source, state, verbose, nested + 1,
#     444                            not nested and not items))
#     445         if not sourcematch("|"):
#
# ~/opt/anaconda3/lib/python3.8/sre_parse.py in _parse(source, state, verbose, nested, first)
#     666                 item = None
#     667             if not item or item[0][0] is AT:
# --> 668                 raise source.error("nothing to repeat",
#     669                                    source.tell() - here + len(this))
#     670             if item[0][0] in _REPEATCODES:
#
# error: nothing to repeat at position 23

# %%
print (len (list_a))
print (list_a[0])
# Out:
# 33
# <th class="classified-table__header" scope="row">Available as of</th>

# %%
print (len (list_a[3]))
# Out:
# 131

# %%
print ([list_a[-1].split()])
# Out:
# [['<th', 'class="classified-table__header"', 'scope="row">Cadastral', 'income</th>']]

# %%
element = list_a[-1][49:]
print (element)
print (element[:-5])
# Out:
# Cadastral income</th>
# Cadastral income

# %%
headers=[]
for n in list_a:
    cut_b = n[49:]
    cut_e = cut_b[:-5]
    headers.append(cut_e)
    
print(headers[-1])

final_headers=[]  

for m in headers:
    str_header = " "
    detect=re.findall("([A-z]+) " ,m )
    print (detect)

    str_header = str_header.join(detect)
    
    final_headers.append(str_header)
    



for header in final_headers:
    print (header)
# Out:
# Cadastral income
# ['Available', 'as']
# ['Neighbourhood', 'or']
# ['Building']
# []
# ['Outdoor', 'parking']
# ['Living']
# ['Kitchen']
# []
# ['Bedroom']
# ['Bedroom']
# ['Bedroom']
# []
# []
# ['Surface', 'of', 'the']
# ['Land', 'plot', 'to']
# ['Flat']
# ['Connection', 'to', 'sewer']
# ['water']
# ['Garden']
# []
# ['Terrace']
# ['Number', 'of']
# ['Primary', 'energy']
# ['Energy']
# ['Reference', 'number', 'of', 'the', 'EPC']
# []
# ['Yearly', 'theoretical', 'total', 'energy']
# ['Heating']
# ['Double']
# ['Planning', 'permission']
# ['Latest', 'land', 'use']
# []
# ['Cadastral']
# Available as
# Neighbourhood or
# Building
#
# Outdoor parking
# Living
# Kitchen
#
# Bedroom
# Bedroom
# Bedroom
#
#
# Surface of the
# Land plot to
# Flat
# Connection to sewer
# water
# Garden
#
# Terrace
# Number of
# Primary energy
# Energy
# Reference number of the EPC
#
# Yearly theoretical total energy
# Heating
# Double
# Planning permission
# Latest land use
#
# Cadastral

# %%
list_bb=[]
list_b = []
for table in soup.find_all("table"):
        for td in soup.find_all("td"):
            list_bb.append(str(td))
print (len(list_bb))   
for i in range(len(list_a)):
    list_b.append(list_bb[i])
    
    print ("*****")
    print (list_bb[i])
print (len(list_b))
# Out:
# 204
# *****
# <td class="classified-table__data">
#                                     Immediately
#                                 </td>
# *****
# <td class="classified-table__data">
#                                     Pietrain
#                                 </td>
# *****
# <td class="classified-table__data">
#                                     As new
#                                 </td>
# *****
# <td class="classified-table__data">
#                                     3
#                                 </td>
# *****
# <td class="classified-table__data">2</td>
# *****
# <td class="classified-table__data">
#                                     180
#
#                                     <span class="abbreviation">
# <span aria-hidden="true">
#                                             m²                                        </span>
# <span class="sr-only">
#                                             square meters
#                                         </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">
#                                     USA hyper equipped
#                                 </td>
# *****
# <td class="classified-table__data">3</td>
# *****
# <td class="classified-table__data">
#                                         12
#
#                                         <span class="abbreviation">
# <span aria-hidden="true">
#                                                 m²                                            </span>
# <span class="sr-only">
#                                                 square meters
#                                             </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">
#                                         15
#
#                                         <span class="abbreviation">
# <span aria-hidden="true">
#                                                 m²                                            </span>
# <span class="sr-only">
#                                                 square meters
#                                             </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">
#                                         9
#
#                                         <span class="abbreviation">
# <span aria-hidden="true">
#                                                 m²                                            </span>
# <span class="sr-only">
#                                                 square meters
#                                             </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">1</td>
# *****
# <td class="classified-table__data">2</td>
# *****
# <td class="classified-table__data">
#                                         330
#
#                                         <span class="abbreviation">
# <span aria-hidden="true">
#                                                 m²
#                                             </span>
# <span class="sr-only">
#                                                 square meters
#                                             </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">Yes
#                                     </td>
# *****
# <td class="classified-table__data">Yes
#                                     </td>
# *****
# <td class="classified-table__data">
#                                         Connected
#                                     </td>
# *****
# <td class="classified-table__data">
#                                         Yes
#                                     </td>
# *****
# <td class="classified-table__data">
#                                     1600
#                                     <span class="abbreviation">
# <span aria-hidden="true">
#                                             m²
#                                         </span>
# <span class="sr-only">
#                                             square meters
#                                         </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">Yes
#                                 </td>
# *****
# <td class="classified-table__data">
#                                     South West
#                                 </td>
# *****
# <td class="classified-table__data">2</td>
# *****
# <td class="classified-table__data">
#
#                                         117
#
#                                         <span class="abbreviation">
# <span aria-hidden="true">
#                                          kWh/m²
#                                     </span>
# <span class="sr-only">
#                                         kilowatt hour per square meters
#                                     </span>
# </span>
# </td>
# *****
# <td class="classified-table__data">
#                                                                     C
#                                                             </td>
# *****
# <td class="classified-table__data">
#                                                                     20180710015175
#                                                             </td>
# *****
# <td class="classified-table__data">
#                                                                     Not specified
#                                                             </td>
# *****
# <td class="classified-table__data">
#                                     36031 kWh/year
#                                 </td>
# *****
# <td class="classified-table__data">
#                                 Gas
#                             </td>
# *****
# <td class="classified-table__data">
#                                 Yes
#                             </td>
# *****
# <td class="classified-table__data">Yes
#                                 </td>
# *****
# <td class="classified-table__data">
#                                     Living area (residential, urban or rural)
#                                 </td>
# *****
# <td class="classified-table__data">
# <span aria-hidden="true">
#                                                                                         € 350,000
#                                         </span>
# <span class="sr-only">
#                                                                                         350000 €
#                                         </span>
# </td>
# *****
# <td class="classified-table__data">
# <span aria-hidden="true">
#                                             € 413
#                                         </span>
# <span class="sr-only">
#                                             413 €
#                                         </span>
# </td>
# 33

# %%
values = []

for n in list_b:
    cut_b = n[35:]
    
    cut_b=cut_b.replace("</td>", "")
    cut_b=cut_b.replace("abbreviation", "")
    cut_b=cut_b.replace("true", "")
    cut_b=cut_b.replace("sr-only", "")
    cut_b=cut_b.replace("<span class=", "")
    cut_b=cut_b.replace("<span aria-hidden=", "")
    cut_b=cut_b.replace("</span>", "")
    values.append(cut_b)
    
    
    cut_b=cut_b[:130]
    print (cut_b)
    print ("______________________________________________________")
    
#cut_e = cut_b[:-5]
for v in values:
    str_header = " "
    detect=re.findall("([A-z]+)| " ,m )
    print (detect)
# Out:
#                                     Immediately
#
# ______________________________________________________
#
#                                     Pietrain
#
# ______________________________________________________
#
#                                     As new
#
# ______________________________________________________
#
#                                     3
#
# ______________________________________________________
# 2
# ______________________________________________________
#
#                                     180
#
#                                     "">
# "">
#
# ______________________________________________________
#
#                                     USA hyper equipped
#
# ______________________________________________________
# 3
# ______________________________________________________
#
#                                         12
#
#                                         "">
# "">
#
# ______________________________________________________
#
#                                         15
#
#                                         "">
# "">
#
# ______________________________________________________
#
#                                         9
#
#                                         "">
# "">
#
# ______________________________________________________
# 1
# ______________________________________________________
# 2
# ______________________________________________________
#
#                                         330
#
#                                         "">
# "">
#
# ______________________________________________________
# Yes
#
# ______________________________________________________
# Yes
#
# ______________________________________________________
#
#                                         Connected
#
# ______________________________________________________
#
#                                         Yes
#
# ______________________________________________________
#
#                                     1600
#                                     "">
# "">
#
# ______________________________________________________
# Yes
#
# ______________________________________________________
#
#                                     South West
#
# ______________________________________________________
# 2
# ______________________________________________________
#
#
#                                         117
#
#                                         "">
# "">
# ______________________________________________________
#
#                                                                     C
#
# ______________________________________________________
#
#                                                                     20180710015175
#
# ______________________________________________________
#
#                                                                     Not specified
#
# ______________________________________________________
#
#                                     36031 kWh/year
#
# ______________________________________________________
#
#                                 Gas
#
# ______________________________________________________
#
#                                 Yes
#
# ______________________________________________________
# Yes
#
# ______________________________________________________
#
#                                     Living area (residential, urban or rural)
#
# ______________________________________________________
#
# "">
#                                                                                         € 350,000
#
# ______________________________________________________
#
# "">
#                                             € 413
#
# "">
#
# ______________________________________________________

# %%
selma="selma"
print (selma[:2])
# Out:
# se
